# %% [markdown]
# # Task 5: Interactive Business Dashboard (Streamlit)
#
# ## Objective
# The goal is to build an interactive dashboard to analyze sales, profit, and customer performance.
#
# ## Step 1: Data Cleaning and Preparation
#
# In this step, we will:
# - Load the dataset
# - Check for missing values
# - Fix data types
# - Prepare data for dashboard usage

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# Load dataset
df = pd.read_csv('superstore.csv', sep=',')

# Preview
df.head()
# Out:
#           Category         City        Country Customer.ID     Customer.Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    Discount Market  记录数               Order.Date        Order.ID  ... Sales  \
# 0       0.0     US    1  2011-01-07 00:00:00.000  CA-2011-130813  ...    19
# 1       0.0     US    1  2011-01-21 00:00:00.000  CA-2011-148614  ...    19
# 2       0.0     US    1  2011-08-05 00:00:00.000  CA-2011-118962  ...    21
# 3       0.0     US    1  2011-08-05 00:00:00.000  CA-2011-118962  ...   111
# 4       0.0     US    1  2011-09-29 00:00:00.000  CA-2011-146969  ...     6
#
# ...

# %%
print("Shape:", df.shape)

print("\nColumns:")
print(df.columns.tolist())

df.info()
# Out:
# Shape: (51290, 27)
#
# Columns:
# ['Category', 'City', 'Country', 'Customer.ID', 'Customer.Name', 'Discount', 'Market', '记录数', 'Order.Date', 'Order.ID', 'Order.Priority', 'Product.ID', 'Product.Name', 'Profit', 'Quantity', 'Region', 'Row.ID', 'Sales', 'Segment', 'Ship.Date', 'Ship.Mode', 'Shipping.Cost', 'State', 'Sub.Category', 'Year', 'Market2', 'weeknum']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        51290 non-null  object
#  1   City            51290 non-null  object
#  2   Country         51290 non-null  object
#  3   Customer.ID     51290 non-null  object
#  4   Customer.Name   51290 non-null  object
#  5   Discount        51290 non-null  float64
#  6   Market          51290 non-null  object
#  7   记录数             51290 non-null  int64
#  8   Order.Date      51290 non-null  object
# ...

# %%
print("Missing Values:\n")
print(df.isnull().sum())
# Out:
# Missing Values:
#
# Category          0
# City              0
# Country           0
# Customer.ID       0
# Customer.Name     0
# Discount          0
# Market            0
# 记录数               0
# Order.Date        0
# Order.ID          0
# Order.Priority    0
# Product.ID        0
# Product.Name      0
# Profit            0
# Quantity          0
# Region            0
# Row.ID            0
# Sales             0
# Segment           0
# Ship.Date         0
# Ship.Mode         0
# Shipping.Cost     0
# State             0
# Sub.Category      0
# Year              0
# Market2           0
# weeknum           0
# dtype: int64

# %%
# Fill missing values (if any)
df.fillna(method='ffill', inplace=True)

# %%
# Convert Order Date to datetime
df['Order.Date'] = pd.to_datetime(df['Order.Date'])

# Check again
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        51290 non-null  object
#  1   City            51290 non-null  object
#  2   Country         51290 non-null  object
#  3   Customer.ID     51290 non-null  object
#  4   Customer.Name   51290 non-null  object
#  5   Discount        51290 non-null  float64
#  6   Market          51290 non-null  object
#  7   记录数             51290 non-null  int64
#  8   Order.Date      51290 non-null  datetime64[ns]
#  9   Order.ID        51290 non-null  object
#  10  Order.Priority  51290 non-null  object
#  11  Product.ID      51290 non-null  object
#  12  Product.Name    51290 non-null  object
#  13  Profit          51290 non-null  float64
#  14  Quantity        51290 non-null  int64
#  15  Region          51290 non-null  object
#  16  Row.ID          51290 non-null  int64
# ...

# %%
print("Total Sales:", df['Sales'].sum())
print("Total Profit:", df['Profit'].sum())
# Out:
# Total Sales: 12642905
# Total Profit: 1467457.2912800002

# %%
df = df[[
    'Order.Date',
    'Region',
    'Category',
    'Sub.Category',
    'Customer.Name',
    'Sales',
    'Profit'
]]

df.head()
# Out:
#   Order.Date Region         Category Sub.Category     Customer.Name  Sales  \
# 0 2011-01-07   West  Office Supplies        Paper  Lycoris Saunders     19
# 1 2011-01-21   West  Office Supplies        Paper     Mark Van Huff     19
# 2 2011-08-05   West  Office Supplies        Paper      Chad Sievert     21
# 3 2011-08-05   West  Office Supplies        Paper      Chad Sievert    111
# 4 2011-09-29   West  Office Supplies        Paper    Arthur Prichep      6
#
#     Profit
# 0   9.3312
# 1   9.2928
# 2   9.8418
# 3  53.2608
# 4   3.1104

# %% [markdown]
# ## Conclusion (Step 1)
#
# - Dataset was successfully loaded and explored.
# - Missing values were handled.
# - Data types were corrected (Order Date converted to datetime).
# - Relevant columns were selected for dashboard creation.
#
# The dataset is now clean and ready for building the Streamlit dashboard.

# %%
# !pip install streamlit
import streamlit as st
import pandas as pd

# Page config
st.set_page_config(
    page_title="Business Dashboard",
    layout="wide"
)

# Title
st.title("📊 Sales & Profit Dashboard")
st.markdown("Analyze sales, profit, and customer performance")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 61.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 104.8 MB/s eta 0:00:00
# ...
# 2026-04-13 16:09:57.241 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:09:57.242 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:09:57.394
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2026-04-13 16:09:57.395 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:09:57.397 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
@st.cache_data
def load_data():
    # Load dataset from the local file which was previously cleaned
    # Ensure to use the correct separator (comma) as identified before
    df_loaded = pd.read_csv('superstore.csv', sep=',')

    # Convert Order Date to datetime, using the correct column name 'Order.Date'
    df_loaded['Order.Date'] = pd.to_datetime(df_loaded['Order.Date'])

    # Select relevant columns as identified in previous steps
    df_processed = df_loaded[[
        'Order.Date',
        'Region',
        'Category',
        'Sub.Category', # Corrected from 'Sub-Category' based on df.columns.tolist()
        'Customer.Name', # Corrected from 'Customer Name' based on df.columns.tolist()
        'Sales',
        'Profit'
    ]]
    return df_processed

df = load_data()
# Out:
# 2026-04-13 16:10:00.781 No runtime found, using MemoryCacheStorageManager
# 2026-04-13 16:10:00.783 No runtime found, using MemoryCacheStorageManager
# 2026-04-13 16:10:00.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
st.subheader("Dataset Preview")
st.dataframe(df.head())
# Out:
# 2026-04-13 16:10:04.915 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:10:04.917 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:10:04.918 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:10:05.003 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:10:05.011 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:10:05.016 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# Create columns
col1, col2 = st.columns(2)

with col1:
    st.metric("Total Sales", "Loading...")

with col2:
    st.metric("Total Profit", "Loading...")
# Out:
# 2026-04-13 16:10:06.449 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:10:06.453 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:10:06.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:10:06.459 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:10:06.460 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:10:06.464 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:10:06.466 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# !streamlit run app.py
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.24.82.49:8501
#
#   Stopping...

# %%
# %%writefile app.py

import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt

# ==============================
# PAGE CONFIG
# ==============================
st.set_page_config(
    page_title="Business Dashboard",
    layout="wide"
)

st.title("📊 Sales & Profit Dashboard")
st.markdown("Analyze sales, profit, and customer performance")

# ==============================
# LOAD DATA
# ==============================
@st.cache_data
def load_data():
    # Load dataset from the local file
    df_loaded = pd.read_csv('superstore.csv', sep=',')
    df_loaded['Order.Date'] = pd.to_datetime(df_loaded['Order.Date'])

    # Select relevant columns and correct column names
    df_processed = df_loaded[[
        'Order.Date',
        'Region',
        'Category',
        'Sub.Category', # Corrected from 'Sub-Category'
        'Customer.Name', # Corrected from 'Customer Name'
        'Sales',
        'Profit'
    ]]
    return df_processed

df = load_data()

# ==============================
# SIDEBAR FILTERS
# ==============================
st.sidebar.header("🔍 Filters")

region = st.sidebar.multiselect(
    "Select Region",
    df['Region'].unique(),
    default=df['Region'].unique()
)

category = st.sidebar.multiselect(
    "Select Category",
    df['Category'].unique(),
    default=df['Category'].unique()
)

sub_category = st.sidebar.multiselect(
    "Select Sub-Category",
    df['Sub.Category'].unique(), # Corrected from 'Sub-Category'
    default=df['Sub.Category'].unique()
)

# ==============================
# APPLY FILTERS
# ==============================
filtered_df = df[
    (df['Region'].isin(region)) &
    (df['Category'].isin(category)) &
    (df['Sub.Category'].isin(sub_category)) # Corrected from 'Sub-Category'
]

# ==============================
# KPIs
# ==============================
total_sales = filtered_df['Sales'].sum()
total_profit = filtered_df['Profit'].sum()

col1, col2 = st.columns(2)

with col1:
    st.metric("💰 Total Sales", f"${total_sales:,.2f}")

with col2:
    st.metric("📈 Total Profit", f"${total_profit:,.2f}")

# ==============================
# TOP CUSTOMERS
# ==============================
st.subheader("🏆 Top 5 Customers by Sales")

top_customers = (
    filtered_df.groupby('Customer.Name')['Sales'] # Corrected from 'Customer Name'
    .sum()
    .sort_values(ascending=False)
    .head(5)
)

st.dataframe(top_customers)

# ==============================
# CHARTS
# ==============================

# Sales by Category
sales_by_category = filtered_df.groupby('Category')['Sales'].sum()
fig1, ax1 = plt.subplots()
sales_by_category.plot(kind='bar', ax=ax1)
ax1.set_title("Sales by Category")
st.pyplot(fig1)

# Profit by Region
profit_by_region = filtered_df.groupby('Region')['Profit'].sum()
fig2, ax2 = plt.subplots()
profit_by_region.plot(kind='bar', ax=ax2)
ax2.set_title("Profit by Region")
st.pyplot(fig2)

# Sales over time
sales_over_time = filtered_df.groupby('Order.Date')['Sales'].sum() # Corrected from 'Order Date'
fig3, ax3 = plt.subplots()
sales_over_time.plot(ax=ax3)
ax3.set_title("Sales Over Time")
st.pyplot(fig3)

# ==============================
# FOOTER
# ==============================
st.markdown("---")
st.markdown("### 📌 Dashboard Insights")
st.write("This dashboard helps analyze sales trends, profit performance, and customer contributions.")
# Out:
# Overwriting app.py

# %%
st.sidebar.header("🔍 Filters")

region = st.sidebar.multiselect(
    "Select Region",
    options=df['Region'].unique(),
    default=df['Region'].unique()
)

category = st.sidebar.multiselect(
    "Select Category",
    options=df['Category'].unique(),
    default=df['Category'].unique()
)

sub_category = st.sidebar.multiselect(
    "Select Sub-Category",
    options=df['Sub.Category'].unique(),
    default=df['Sub.Category'].unique()
)
# Out:
# 2026-04-13 16:45:00.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:45:00.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:45:00.307 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:45:00.317 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:45:00.318 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:45:00.321 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:45:00.322 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %% [markdown]
# ## View Streamlit App with LocalTunnel

# %%
# Install pyngrok for ngrok functionality
# !pip install pyngrok

# %%
from google.colab import userdata

# Attempt to retrieve the NGROK_AUTH_TOKEN from Colab secrets
ngrok_token = userdata.get('NGROK_AUTH_TOKEN')

if ngrok_token:
    print(f"NGROK_AUTH_TOKEN is set. Its value (first 5 chars): {ngrok_token[:5]}...")
else:
    print("NGROK_AUTH_TOKEN is NOT set or not accessible in Colab secrets. Please ensure it's added.")
# Out:
# NGROK_AUTH_TOKEN is set. Its value (first 5 chars): 3CJK7...

# %%
from pyngrok import ngrok
from google.colab import userdata
import os

# Get your ngrok authtoken from Colab secrets
ngrok_token = userdata.get('NGROK_AUTH_TOKEN')

if ngrok_token:
    # Strip any whitespace characters from the token
    ngrok_token = ngrok_token.strip()
    ngrok.set_auth_token(ngrok_token)
    print(f"NGROK_AUTH_TOKEN set successfully (first 5 chars: {ngrok_token[:5]}...)")

    # Disconnect any existing ngrok tunnels
    ngrok.kill()

    # Open a ngrok tunnel to the Streamlit port (8501)
    public_url = ngrok.connect(8501)
    print(f"Streamlit App URL: {public_url}")

    # Run the Streamlit app in the background
    # !streamlit run app.py &
else:
    print("NGROK_AUTH_TOKEN is NOT set or not accessible in Colab secrets. Please ensure it's added.")
# Out:
# NGROK_AUTH_TOKEN set successfully (first 5 chars: 3CJK7...)
# Streamlit App URL: NgrokTunnel: "https://scope-manger-cosmos.ngrok-free.dev" -> "http://localhost:8501"
#
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.24.82.49:8501

# %%
import os

# Attempt to retrieve the NGROK_AUTH_TOKEN from environment variables
NGROK_AUTH_TOKEN_CHECK = os.environ.get("NGROK_AUTH_TOKEN")

if NGROK_AUTH_TOKEN_CHECK:
    print("NGROK_AUTH_TOKEN is set and accessible. Its value (first 5 chars):", NGROK_AUTH_TOKEN_CHECK[:5] + "...")
else:
    print("NGROK_AUTH_TOKEN is NOT set or not accessible. Please ensure it's added to Colab secrets.")
# Out:
# NGROK_AUTH_TOKEN is NOT set or not accessible. Please ensure it's added to Colab secrets.

# %%
import os

# Access the NGROK_AUTH_TOKEN from Colab secrets
NGROK_AUTH_TOKEN = os.environ.get("NGROK_AUTH_TOKEN")

if NGROK_AUTH_TOKEN:
    print("NGROK_AUTH_TOKEN accessed successfully (first 5 chars):", NGROK_AUTH_TOKEN[:5] + "...")
else:
    print("NGROK_AUTH_TOKEN is not set or accessible in Colab secrets.")
# Out:
# NGROK_AUTH_TOKEN is not set or accessible in Colab secrets.

# %%
# Apply filters
filtered_df = df[
    (df['Region'].isin(region)) &
    (df['Category'].isin(category)) &
    (df['Sub.Category'].isin(sub_category))
]

# %%
total_sales = filtered_df['Sales'].sum()
total_profit = filtered_df['Profit'].sum()

# Top 5 customers
top_customers = (
    filtered_df.groupby('Customer.Name')['Sales']
    .sum()
    .sort_values(ascending=False)
    .head(5)
)

# %%
# KPI layout
col1, col2 = st.columns(2)

with col1:
    st.metric("💰 Total Sales", f"${total_sales:,.2f}")

with col2:
    st.metric("📈 Total Profit", f"${total_profit:,.2f}")
# Out:
# 2026-04-13 16:37:48.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:48.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:48.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:48.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:48.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:48.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:48.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
st.subheader("🏆 Top 5 Customers by Sales")

st.dataframe(top_customers)
# Out:
# 2026-04-13 16:37:48.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:48.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:48.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:48.572 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:48.572 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:48.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
import matplotlib.pyplot as plt

# Group data
sales_by_category = filtered_df.groupby('Category')['Sales'].sum()

# Plot
fig1, ax1 = plt.subplots()
sales_by_category.plot(kind='bar', ax=ax1)

ax1.set_title("Sales by Category")
ax1.set_xlabel("Category")
ax1.set_ylabel("Sales")

st.pyplot(fig1)
# Out:
# 2026-04-13 16:37:48.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:48.811 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:48.813 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:48.813 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
profit_by_region = filtered_df.groupby('Region')['Profit'].sum()

fig2, ax2 = plt.subplots()
profit_by_region.plot(kind='bar', ax=ax2)

ax2.set_title("Profit by Region")
ax2.set_xlabel("Region")
ax2.set_ylabel("Profit")

st.pyplot(fig2)
# Out:
# 2026-04-13 16:37:48.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:49.315 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:49.316 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:49.317 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# Time series
sales_over_time = filtered_df.groupby('Order.Date')['Sales'].sum()

fig3, ax3 = plt.subplots()
sales_over_time.plot(ax=ax3)

ax3.set_title("Sales Over Time")
ax3.set_xlabel("Date")
ax3.set_ylabel("Sales")

st.pyplot(fig3)
# Out:
# 2026-04-13 16:37:49.418 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:49.756 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:49.757 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:49.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
col1, col2 = st.columns(2)

with col1:
    st.pyplot(fig1)

with col2:
    st.pyplot(fig2)

st.pyplot(fig3)
# Out:
# 2026-04-13 16:37:49.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:49.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:49.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:49.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:49.910 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:49.912 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:49.913 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
st.markdown("---")
# Out:
# 2026-04-13 16:37:50.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:50.591 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:50.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.markdown("### 📌 Dashboard Insights")
st.write("This dashboard provides insights into sales performance, profit trends, and top customers.")
# Out:
# 2026-04-13 16:37:50.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:50.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:50.612 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:50.616 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:50.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-13 16:37:50.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# ## Final Conclusion
#
# - An interactive Streamlit dashboard was successfully developed.
# - Users can filter data based on Region, Category, and Sub-Category.
# - Key performance indicators such as Total Sales and Profit are dynamically updated.
# - Visualizations provide insights into sales trends and regional performance.
#
# This dashboard helps businesses make data-driven decisions and monitor performance effectively.
